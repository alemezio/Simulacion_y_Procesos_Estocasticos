# %% [markdown]
# Ejemplo del libro de Ciaburro: https://github.com/PacktPublishing/Hands-On-Simulation-Modeling-with-Python-Second-Edition

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cost_function(x):
    return x*np.sin(2.1*x+1)

# %%
x= np.linspace(0,10,1000)

plt.plot(x,cost_function(x))
plt.xlabel('X')
plt.ylabel('Cost Function')
plt.show()

# %%
temp = 2000
iter = 2000
step_size = 0.1
np.random.seed(15)
xi = np.random.uniform(min(x), max(x))
E_xi = cost_function(xi)
xit, E_xit = xi, E_xi
cost_func_eval = []
acc_prob = 1

for i in range(iter):
    xstep = xit + np.random.randn() * step_size  
    E_step = cost_function(xstep)
    if E_step < E_xi:
        xi, E_xi = xstep, E_step
        cost_func_eval.append(E_xi)
        print('Iteration = ',i, 'x_min = ',xi,'Global Minimum =', E_xi,
              'Acceptance Probability =', acc_prob)
    else:
        diff_energy = E_step - E_xit
        t = temp /(i + 1)
        acc_prob = np.exp(-diff_energy/ t)
        if diff_energy < 0 or np.random.randn() < acc_prob:
            xit, E_xit = xstep, E_step
# Out:
# Iteration =  0 x_min =  8.352060345432603 Global Minimum = -2.549691087509061 Acceptance Probability = 1
# Iteration =  2 x_min =  8.213190852035115 Global Minimum = -4.650083681682615 Acceptance Probability = 1.0014687547383714
# Iteration =  18 x_min =  8.132760405406172 Global Minimum = -5.665931377794822 Acceptance Probability = 1.0211225407931368
# Iteration =  23 x_min =  8.070429200185638 Global Minimum = -6.33007627751385 Acceptance Probability = 1.002534238516436
# Iteration =  28 x_min =  8.06883789094669 Global Minimum = -6.345518899760686 Acceptance Probability = 1.018934831079083
# Iteration =  29 x_min =  8.018594305582075 Global Minimum = -6.79256612450463 Acceptance Probability = 1.018934831079083
# Iteration =  222 x_min =  7.9943149390793 Global Minimum = -6.979717668161215 Acceptance Probability = 0.7351155697106506
# Iteration =  226 x_min =  7.979015788532285 Global Minimum = -7.087732346089214 Acceptance Probability = 0.9870955336512466
# Iteration =  236 x_min =  7.897276916476206 Global Minimum = -7.531554738615108 Acceptance Probability = 1.119155361867553
# Iteration =  238 x_min =  7.8173880645992995 Global Minimum = -7.7433318216955085 Acceptance Probability = 1.0505497599705518
# Iteration =  249 x_min =  7.799331682287206 Global Minimum = -7.760494372648758 Acceptance Probability = 0.9567532716322495
# Iteration =  409 x_min =  7.797885713339582 Global Minimum = -7.7613798979094 Acceptance Probability = 0.9833924348386354
# Iteration =  415 x_min =  7.769962636692329 Global Minimum = -7.764305493534673 Acceptance Probability = 1.1104940008747028
# Iteration =  429 x_min =  7.774121115404246 Global Minimum = -7.765574579488386 Acceptance Probability = 0.9582198220945425
# Iteration =  480 x_min =  7.778462558098035 Global Minimum = -7.766263987898334 Acceptance Probability = 0.8420410851042163
# Iteration =  606 x_min =  7.7797632824082426 Global Minimum = -7.766344035277719 Acceptance Probability = 1.0720558930897075
# Iteration =  615 x_min =  7.781791131062916 Global Minimum = -7.766352401323683 Acceptance Probability = 1.0049420470340065
# Iteration =  1186 x_min =  7.781732318618965 Global Minimum = -7.7663541567656695 Acceptance Probability = 1.323007401982197

# %%
plt.plot(cost_func_eval, 'bs--')
plt.xlabel('Improvement Step')
plt.ylabel('Cost Function improvement')
plt.show()
