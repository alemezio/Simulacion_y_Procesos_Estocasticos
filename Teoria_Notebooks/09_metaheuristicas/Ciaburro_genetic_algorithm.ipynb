# %% [markdown]
# Ejemplo del libro de Ciaburro: https://github.com/PacktPublishing/Hands-On-Simulation-Modeling-with-Python-Second-Edition

# %%
import numpy as np

# %%
var_values = [1,-3,4.5,2]
num_coeff = 4
pop_chrom = 10 
sel_rate = 5

pop_size = (pop_chrom,num_coeff) 
pop_new = np.random.uniform(low=-10.0, high=10.0, size=pop_size)
print(pop_new)
# Out:
# [[ 1.26713439  8.36711277  3.17002586  7.89568735]
#  [-4.61925737 -7.07782573  1.87942385  6.52620268]
#  [ 4.63770283  7.43863722  7.1053577   3.83291799]
#  [-1.72884071  4.72361439 -6.70723216 -7.24834753]
#  [-0.28746463 -2.64086959  6.20521148 -1.02569629]
#  [ 7.83415085 -2.85796613 -7.78725575  3.78721145]
#  [ 7.50178243 -1.37297815 -8.95026437 -0.63519445]
#  [-2.15364223 -9.56200488  3.44920517 -8.91439619]
#  [ 0.08824716  7.05184597 -1.91751036  2.04807437]
#  [-7.52080973  0.0655907   1.44843478 -2.74611741]]

# %%
num_gen = 100
for k in range(num_gen):
    fitness = np.sum(pop_new *var_values, axis=1)
    par_sel = np.empty((sel_rate, pop_new.shape[1]))
    print("Current generation = ", k)
    print("Best fitness value : ", np.max(fitness))
    
    for i in range(sel_rate):
        sel_id = np.where(fitness == np.max(fitness))
        sel_id = sel_id[0][0]
        par_sel[i, :] = pop_new[sel_id, :]
        fitness[sel_id]=np.min(fitness)

    offspring_size=(pop_chrom-sel_rate, num_coeff)
    offspring = np.empty(offspring_size)
    crossover_lenght = int(offspring_size[1]/2)
    
    for j in range(offspring_size[0]):
        par1_id = np.random.randint(0,par_sel.shape[0])
        par2_id = np.random.randint(0,par_sel.shape[0])
        offspring[j, 0:crossover_lenght] = par_sel[par1_id, 0:crossover_lenght]
        offspring[j, crossover_lenght:] = par_sel[par2_id, crossover_lenght:]
    

    for m in range(offspring.shape[0]):
        mut_val = np.random.uniform(-1.0, 1.0)
        mut_id = np.random.randint(0,par_sel.shape[1])
        offspring[m, mut_id] = offspring[m, mut_id] + mut_val 

    pop_new[0:par_sel.shape[0], :] = par_sel
    pop_new[par_sel.shape[0]:, :] = offspring


fitness = np.sum(pop_new *var_values, axis=1)
best_id = np.where(fitness == np.max(fitness))
print("Optimized coefficient values = ", pop_new[best_id, :])
print("Maximum value of y = ", fitness[best_id])
# Out:
# Current generation =  0
# Best fitness value :  38.12403252329326
# Current generation =  1
# Best fitness value :  55.0279756534466
# Current generation =  2
# Best fitness value :  55.0279756534466
# Current generation =  3
# Best fitness value :  55.0279756534466
# Current generation =  4
# Best fitness value :  55.0279756534466
# Current generation =  5
# Best fitness value :  57.100625961104285
# Current generation =  6
# Best fitness value :  57.100625961104285
# Current generation =  7
# Best fitness value :  57.100625961104285
# Current generation =  8
# Best fitness value :  59.13849649815927
# Current generation =  9
# Best fitness value :  59.13849649815927
# Current generation =  10
# Best fitness value :  62.58073698635221
# Current generation =  11
# Best fitness value :  63.555764468574495
# Current generation =  12
# Best fitness value :  63.79868992784346
# Current generation =  13
# Best fitness value :  67.44410101288304
# Current generation =  14
# Best fitness value :  67.44410101288304
# Current generation =  15
# Best fitness value :  71.09690189937461
# Current generation =  16
# Best fitness value :  73.63133778914397
# Current generation =  17
# Best fitness value :  77.44832409490455
# Current generation =  18
# Best fitness value :  77.44832409490455
# Current generation =  19
# Best fitness value :  78.54101544080173
# Current generation =  20
# Best fitness value :  81.44492169319267
# Current generation =  21
# Best fitness value :  82.1490363297995
# Current generation =  22
# Best fitness value :  83.5034301417837
# Current generation =  23
# Best fitness value :  87.50007053010707
# Current generation =  24
# Best fitness value :  87.96599691290224
# Current generation =  25
# Best fitness value :  89.31314792539108
# Current generation =  26
# Best fitness value :  89.46263674600408
# Current generation =  27
# Best fitness value :  92.47901166768355
# Current generation =  28
# Best fitness value :  92.88770127259718
# Current generation =  29
# Best fitness value :  92.88770127259718
# Current generation =  30
# Best fitness value :  93.62687458596643
# Current generation =  31
# Best fitness value :  95.35304061732991
# Current generation =  32
# Best fitness value :  95.35304061732991
# Current generation =  33
# Best fitness value :  96.82784863188944
# Current generation =  34
# Best fitness value :  96.89758995558357
# Current generation =  35
# Best fitness value :  98.14694906869492
# Current generation =  36
# Best fitness value :  102.08687303197597
# Current generation =  37
# Best fitness value :  102.08687303197597
# Current generation =  38
# Best fitness value :  102.08687303197597
# Current generation =  39
# Best fitness value :  102.08687303197597
# Current generation =  40
# Best fitness value :  102.77072479691371
# Current generation =  41
# Best fitness value :  106.17713971613004
# Current generation =  42
# Best fitness value :  106.19878250779225
# Current generation =  43
# Best fitness value :  106.19878250779225
# Current generation =  44
# Best fitness value :  111.70447182466714
# Current generation =  45
# Best fitness value :  111.70447182466714
# Current generation =  46
# Best fitness value :  112.61208553264662
# Current generation =  47
# Best fitness value :  114.66606501527824
# Current generation =  48
# Best fitness value :  116.74282592279825
# Current generation =  49
# Best fitness value :  117.23401548252876
# Current generation =  50
# Best fitness value :  119.53269723944204
# Current generation =  51
# Best fitness value :  119.53269723944204
# Current generation =  52
# Best fitness value :  119.53468172722145
# Current generation =  53
# Best fitness value :  122.794697107401
# Current generation =  54
# Best fitness value :  122.794697107401
# Current generation =  55
# Best fitness value :  124.83714148123444
# Current generation =  56
# Best fitness value :  126.97772213920068
# Current generation =  57
# Best fitness value :  127.83360237099127
# Current generation =  58
# Best fitness value :  132.02973382190402
# Current generation =  59
# Best fitness value :  132.02973382190402
# Current generation =  60
# Best fitness value :  133.5348150332161
# Current generation =  61
# Best fitness value :  133.5348150332161
# Current generation =  62
# Best fitness value :  134.7705740117782
# Current generation =  63
# Best fitness value :  134.7705740117782
# Current generation =  64
# Best fitness value :  135.4661180208221
# Current generation =  65
# Best fitness value :  138.08135305302528
# Current generation =  66
# Best fitness value :  138.08135305302528
# Current generation =  67
# Best fitness value :  139.88851049547543
# Current generation =  68
# Best fitness value :  141.6325162580962
# Current generation =  69
# Best fitness value :  142.80888919711498
# Current generation =  70
# Best fitness value :  142.80888919711498
# Current generation =  71
# Best fitness value :  143.0901508972912
# Current generation =  72
# Best fitness value :  146.63564729722407
# Current generation =  73
# Best fitness value :  146.63564729722407
# Current generation =  74
# Best fitness value :  148.1347771137008
# Current generation =  75
# Best fitness value :  149.21303187894418
# Current generation =  76
# Best fitness value :  149.38729384042313
# Current generation =  77
# Best fitness value :  149.88940294586197
# Current generation =  78
# Best fitness value :  150.7654944993094
# Current generation =  79
# Best fitness value :  152.27608672681058
# Current generation =  80
# Best fitness value :  157.47186594211186
# Current generation =  81
# Best fitness value :  157.47186594211186
# Current generation =  82
# Best fitness value :  157.8750661347961
# Current generation =  83
# Best fitness value :  158.0411195459643
# Current generation =  84
# Best fitness value :  161.21021902059806
# Current generation =  85
# Best fitness value :  164.2038707075877
# Current generation =  86
# Best fitness value :  164.2038707075877
# Current generation =  87
# Best fitness value :  164.2038707075877
# Current generation =  88
# Best fitness value :  164.52485162817717
# Current generation =  89
# Best fitness value :  165.13294315014238
# Current generation =  90
# Best fitness value :  165.13294315014238
# Current generation =  91
# Best fitness value :  167.8217489516265
# Current generation =  92
# Best fitness value :  168.87037375200703
# Current generation =  93
# Best fitness value :  170.07061613604426
# Current generation =  94
# Best fitness value :  170.07061613604426
# Current generation =  95
# Best fitness value :  173.18923806324116
# Current generation =  96
# Best fitness value :  175.0285132187146
# Current generation =  97
# Best fitness value :  176.1014260743149
# Current generation =  98
# Best fitness value :  176.1014260743149
# Current generation =  99
# Best fitness value :  177.75099344575492
# Optimized coefficient values =  [[[ -0.79153642 -26.62438549  20.53939907   3.12103879]]]
# Maximum value of y =  [177.75099345]
